# %% [markdown]
# <a href="https://colab.research.google.com/github/kellyluu94/machine-learning/blob/main/Linear_Regression_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f = lambda x: -3*x**2 + 2*x + 20

import numpy as np, matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)

# %%
from numpy.random import normal, seed, uniform

np.random.seed(42)

x_train = np.linspace(-10, 10, 20).reshape(-1, 1)
y = f(x_train) * (1 + normal(scale=0.2, size=x_train.shape)) + normal(scale=1.3, size=x_train.shape)

plt.plot(x, f(x))
plt.scatter(x_train, y)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

model = make_pipeline(PolynomialFeatures(degree=3), LinearRegression())
model.fit(x_train, y)
plt.scatter(x_train, y)
plt.plot(x, model.predict(x.reshape(-1, 1)))
